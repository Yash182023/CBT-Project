# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import re

# %%
df=pd.read_csv('Introtherapy_data.csv')
Dataf=pd.DataFrame(df)
Dataf
# Out:
#      Answers  Weight
# 0        sad      15
# 1       evil      12
# 2  very less      18
# 3      worst      23
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# Dataf['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# Dataf.groupby('Answers').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
df2=pd.read_csv("ADHD_data.csv")
Dataf1=pd.DataFrame(df2)
Dataf1
# Out:
#      Answers  Weight
# 0   Not good      21
# 1  Sometimes      22
# 2   patterns      12
# 3    feeling      30

# %%
df3=pd.read_csv("PTSD_data.csv")
Dataf2=pd.DataFrame(df3)
Dataf2
# Out:
#      Answers  Weight
# 0       past      23
# 1  childhood      11
# 2    parents      16
# 3        bad      17
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# Dataf2['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# Dataf2.groupby('Answers').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df4=pd.read_csv("BPD_data.csv")
Dataf3=pd.DataFrame(df4)
Dataf3
# Out:
#    Answers  Weight
# 0     less      13
# 1  anxiety      15
# 2   stress      19
# 3      sad      21

# %%
if 'Answers' in df.columns and 'Weight' in df.columns:
    weight_column = df['Weight']
    X = df['Answers']
    y = weight_column
else:
    print("Column names 'Answers' and 'Weight' not found in the DataFrame.")

# %%
import pandas as pd

# Load the CSV file with header row
df = pd.read_csv("Introtherapy_data.csv")

# Check the column names in the DataFrame (case-sensitive)
print(df.columns)

# Access the columns with the correct case
X = df['Answers']
y = df['Weight']
# Out:
# Index(['Answers', 'Weight'], dtype='object')

# %%
X2 = df2['Answers']
y2 = df2['Weight']

# %%
X3 = df3['Answers']
y3 = df3['Weight']

# %%
X4 = df4['Answers']
y4 = df4['Weight']

# %%
port_stem = PorterStemmer()

# %%
def stemming(content):
    stemmed_content = re.sub('[^a-zA-Z]',' ',content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
    stemmed_content = ' '.join(stemmed_content)
    return stemmed_content

# %%
df['Answers']=df['Answers'].apply(stemming)

# %%
df2['Answers']=df2['Answers'].apply(stemming)

# %%
df3['Answers']=df3['Answers'].apply(stemming)

# %%
df4['Answers']=df4['Answers'].apply(stemming)

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(X)

X = vectorizer.transform(X)

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(X3)

X3 = vectorizer.transform(X3)

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(X4)

X4 = vectorizer.transform(X4)

# %%
print(X)
# print(X2)
# print(X3)
# print(X4)
# Out:
#   (0, 2)	1.0
#   (1, 0)	1.0
#   (2, 3)	0.7071067811865476
#   (2, 1)	0.7071067811865476
#   (3, 4)	1.0

# %%
print(X2)
# Out:
#   (0, 1)	1.0
#   (1, 3)	1.0
#   (2, 2)	1.0
#   (3, 0)	1.0

# %%
print(y3)
# Out:
# 0    23
# 1    11
# 2    16
# 3    17
# Name: Weight, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the test data : ', training_data_accuracy)
# Out:
# Accuracy score of the test data :  1.0

# %%
X_new = X_train[1]

prediction = model.predict(X_new)
print(prediction)

if (prediction[0]>10):
  print('You need more therapy')
else:
  print('You are fine')
# Out:
# [18]
# You need more therapy
